# %% [markdown]
# <h1><center>Mengimpor <i>Library</i></center></h1>

# %% [markdown]
# <div class="alert alert-danger">Jika pada saat mengimpor <i>library</i>, terdapat <i>error</i> seperti di bawah ini:<br>
# <tt><font color=black>&emsp;ModuleNotFoundError: No module named 'EXAMPLE'</tt>
#
# Silakan mengunduh library tersebut terlebih dahulu dengan cara mengetikkan perintah berikut ini:<br>
# <tt><font color=black>&emsp;pip install EXAMPLE</tt><br>atau<br>
# <tt><font color=black>&emsp;conda install -c anaconda EXAMPLE</tt></div>

# %%
import numpy as np
import pandas as pd
import re
import json
import dateparser
import datetime

from serpapi import GoogleSearch
from urllib.parse import urlsplit, parse_qsl

# %% [markdown]
# <h1><center>Scraping Ulasan Setiap Cabang Menggunakan SerpAPI</center></title>

# %% [markdown]
# SerpAPI merupakan perusahaan yang menyediakan layanan API. Mereka menawarkan cara yang efisien untuk mengambil hasil pencarian dari berbagai *search engine* seperti Google, Bing, Yahoo, dan sebagainya. Pada kasus ini, kita akan menggunakan salah satu layanan API-nya, yaitu Google Maps API. Berdasarkan [dokumentasi](https://serpapi.com/google-maps-api) resminya:

# %% [markdown]
# <div class="alert alert-info" style="margin: 20px">Our Google Maps API allows you to scrape SERP results from a Google Maps search or places query. The API is accessed through the following endpoint: /search?engine=google_maps. A user may query the following: https://serpapi.com/search?engine=google_maps utilizing a GET request. Head to the <a href='https://serpapi.com/playground?engine=google_maps'>playground</a> for a live and interactive demo.
#
# <br>
#
# Some results may be inaccurate for the provided geographic location. Particularly near me keyword in query will show results not for provided coordinates. Also city, state and zip code can be added to query to refine search. Alternatively <a href='https://serpapi.com/local-results'>local results</a> can be used.</div>

# %% [markdown]
# Masukkan URL cabang yang ingin di-*scrape* ulasannya ke variabel `place_url`untuk mendapatkan ID-nya.

# %%
place_url = "https://www.google.com/maps/place/Auto2000+Garuda/@-6.1613082,106.8451228,17z/data=!4m8!3m7!1s0x2e69f5bbe41da311:0x90c253d6494645da!8m2!3d-6.1613135!4d106.8476977!9m1!1b1!16s%2Fg%2F1tcy13h3?entry=ttu"

place_id = re.search(r"1s(0x.*?)!8m", place_url).group(1)
place_id
# Out:
# '0x2e69f5bbe41da311:0x90c253d6494645da'

# %% [markdown]
# Masukkan API Key ke parameter `api_key`. API Key dapat diakses di [sini](https://serpapi.com/manage-api-key). Misal, jika API Key-nya adalah AbCd, tulis:
#
# `api_key: "AbCd"`

# %%
params = {
    "api_key": "INSERT API KEY HERE", 
    "engine": "google_maps_reviews",
    "hl": "en",
    "data_id": place_id,
    "sort_by": "newestFirst"
}

search = GoogleSearch(params)

# %% [markdown]
# Tentukan batas awal tanggal ulasan yang ingin diambil pada variabel `target_date`. Tuliskan dalam bentuk format `datetime`, yaitu tahun, bulan, tanggal. Jika ingin mengambil ulasan dari tanggal 19 Juli 2023 (*included*), tulis:
#
# `target_date  = datetime.datetime(2023, 7, 19)`
#
# <font color=blue>**NOTE: Jika ingin memodifikasi *code* di bawah ini, silakan mempelajarinya terlebih dahulu di [sini](https://serpapi.com/blog/using-google-maps-reviews-api-from-serpapi/).**</font>

# %%
target_date  = datetime.datetime(2023, 1, 1)
reviews = []
page_num = 0

while True:
    page_num += 1
    results = search.get_dict()

    print(f"Scraping Page {page_num}")

    if "reviews" in results:
        for result in results["reviews"]:
            date_value = result.get("date")
            if len(date_value) > 1:
                if isinstance(date_value, str):
                    review_date = dateparser.parse(date_value).strftime("%Y-%m-%d")
                elif isinstance(date_value, int):
                    review_date = datetime.datetime.fromtimestamp(int(date_value)).strftime("%Y-%m-%d")
            else:
                review_date = np.nan

            if review_date and datetime.datetime.strptime(review_date, "%Y-%m-%d") >= target_date:
                reply = result.get("response", {})
                reply_snippet = reply.get("snippet")
                reply_date = reply.get("date", "")
                if len(reply_date) > 1:
                    if isinstance(reply_date, str):
                        reply_date = dateparser.parse(reply_date).strftime("%Y-%m-%d")
                    elif isinstance(reply_date, int):
                        reply_date = datetime.datetime.fromtimestamp(int(reply_date)).strftime("%Y-%m-%d")
                else:
                    reply_date = np.nan

                reviews.append({
                    "scraped_date": datetime.datetime.now().isoformat(),
                    "name": result["user"]["name"],
                    "link": result["user"]["link"],
                    "thumbnail": result["user"]["thumbnail"],
                    "rating": result["rating"],
                    "review_date": review_date,
                    "review": result["snippet"],
                    "reply_date": reply_date,
                    "reply": reply_snippet,
                    "images": result.get("images"),
                    "local_guide": result["user"].get("local_guide")
                })
            else:
                break
    else:
        print(results.get("error", "Unknown error"))
        break

    if results.get("serpapi_pagination").get("next") and results.get("serpapi_pagination").get("next_page_token"):
        search.params_dict.update(dict(parse_qsl(urlsplit(results["serpapi_pagination"]["next"]).query)))
    else:
        break

print(json.dumps(reviews, indent=2, ensure_ascii=False))
# Out:
# Scraping Page 1
# Scraping Page 2
# Scraping Page 3
# Scraping Page 4
# Scraping Page 5
# Scraping Page 6
# Scraping Page 7
# Your searches for the month are exhausted. You can upgrade plans on SerpApi.com website.
# [
#   {
#     "scraped_date": "2023-06-04T17:04:01.575563",
#     "name": "Sonny Angga",
#     "link": "https://www.google.com/maps/contrib/114008955936441678306?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegQIARBB",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMQ9m7YpAfPfnLIu9BQ-iLu6KUtqWS0jIA1tQe_MAmM=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-28",
#     "review": "(Translated by Google) Thank you Pa Ade for the good and extraordinary service.. 👍👍👍 Recommended sales (Original) Terima kasih Pa Ade atas pelayanan yang baik dan luar biasa.. 👍👍👍 Recommended sales",
#     "reply_date": "2023-05-30",
#     "reply": "(Translated by Google) Good afternoon Mr. Sonny Angga, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang Pak Sonny Angga, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.579560",
#     "name": "Ade Pardana",
#     "link": "https://www.google.com/maps/contrib/105984139737034906453?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegQIARBb",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMRAW9OcUtNoPnTlB95bl2k08ayxbQKBpukkkUD68OI=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-28",
#     "review": "",
#     "reply_date": "2023-05-30",
#     "reply": "(Translated by Google) Good afternoon. Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang. Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.584098",
#     "name": "Cahyadi Wijaya",
#     "link": "https://www.google.com/maps/contrib/117853391246451918623?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegQIARBx",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTteXrw2D9VAcET3Y-ulSoRGbudO7CzCXEo_0yfnG=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-28",
#     "review": "(Translated by Google) Good service, fast, friendly, served by Mr. Ade Perdana, recommended seller👍👍👍 (Original) Pelayanang Baik, Cepat , Ramah, dilayani Pak Ade Perdana, rekomended Seller👍👍👍",
#     "reply_date": "2023-05-30",
#     "reply": "(Translated by Google) Good afternoon Mr. Cahyadi Wijaya, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang Pak Cahyadi Wijaya, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipOaOn_X7eCqcC0qn5nWmA9eyoDGF17oJDbtWfZ8=w100-h100-p-n-k-no"
#     ],
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.588076",
#     "name": "Tukang Review",
#     "link": "https://www.google.com/maps/contrib/104452618708714715903?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegUIARCNAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtdwCpmqJbg3tgwhet5Kb_m6lGWfclutbMOs6w3A=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-28",
#     "review": "(Translated by Google) Auto 2000 Garuda service is great. Thank you for the service to Mas Haris - Marketing 👍 (Original) Pelayanan Auto 2000 Garuda mantap. Terima kasih pelayanannya untuk Mas Haris - Marketing 👍",
#     "reply_date": "2023-05-30",
#     "reply": "(Translated by Google) Good afternoon AutoFamily. Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang AutoFamily. Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.594660",
#     "name": "Yesi Yoto",
#     "link": "https://www.google.com/maps/contrib/102498346974357411577?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegUIARCnAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMSXPKUFvr_8UAGHUX4ENDUPpIsmCtNlpCIrxOMZzA=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-28",
#     "review": "(Translated by Google) Friendly service(Original)Pelayanan ramah",
#     "reply_date": "2023-02-04",
#     "reply": "(Translated by Google) Good afternoon Mr. Yesi Yoto. Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang Pak Yesi Yoto. Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipMmE-lH9X86e7oiloNYvm3UJFVpZGb5lxFEnXuU=w100-h100-p-n-k-no"
#     ],
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.597653",
#     "name": "Henry Saputra",
#     "link": "https://www.google.com/maps/contrib/110303958799399624308?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegUIARDDAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMQi8CFZOGJpZLi9VatcI1S2eaKjKA7L1BWXMloaiQ=s40-c-c0x00000000-cc-rp-mo-ba5-br100",
#     "rating": 1.0,
#     "review_date": "2023-05-14",
#     "review": "(Translated by Google) I don't know if this makes it difficult for car service people or what??? Today May 12, 2023 I want to register for service at auto 2000 Garuda and the telephone is received by the name Hani and I am informed that I have to provide documents first and the telephone continues with the one named Halimah, where it is explained that the new rules per May 8, 2023 if you want to register for service, you must have an ID card and NPWP, I have provided the conditions requested, it happens that my vehicle is in the name of PT and when I check the address on the STNK and NPWP it is different from my current domicile address so I can't be accepted for service, he said I have to change the NPWP address first so that it's appropriate then it can be serviced!!! HALLO Do you want service or administrative order operations??? I asked to speak with the leadership and those in charge but for almost 30 minutes my phone was kept on hold with the excuse that I was not there. In my opinion, the obligation of auto 2000 is to provide after sales service from Toyota. the task of checking data, administration etc must have been running when the person or PT bought the vehicle !!! (Original) Saya tidak tahu apakah ini mempersulit orang servis mobil atau bagaimana ya??? Hari ini 12 mei 2023 Saya mau daftar servis di auto 2000 Garuda dan telp diterima oleh namanya hani dan diinformasikan bahwa harus memberikan dokumen2 dulu dan telp dilanjutkan dengan yg namanya halimah, disana dijelaskan bahwa aturan baru per 08 mei 2023 mau daftar servis harus ada KTP dan NPWP, saya sudah memberikan syarat yg diminta, kebetulan kendaraan saya atas nama PT dan disaat dicek alamat di STNK dan NPWP berbeda dengan alamat domisili saat ini jadi saya gak bisa diterima servis katanya harus rubah alamat NPWP nya dulu biar sesuai baru bisa servis!!! HALLO Ini mau servis atau operasi ketertiban administrasi??? Saya minta bicara dengan pimpinan dan yg bertanggung jawab tapi hampir 30 menit telp saya di hold terus dengan alasan tidak ada ditempat. Menurut saya Kewajiban auto 2000 adalah melakukan pelayanan after sales dari toyota. tugas pengecekan data,administrasi dll pasti sudah berjalan pada saat orang atau PT tersebut membeli kendaraan !!!",
#     "reply_date": "2023-05-14",
#     "reply": "(Translated by Google) Good afternoon Mr. Henry Saputra, Thank you for the review provided, sorry for the inconvenience felt in our booking service process. It will be input for us to be better in the future. Please provide confirmation via WA booking service Auto2000 Garuda so we can follow up. Thank You (Original) Selamat siang Pak Henry Saputra, Terima kasih atas review yang diberikan, mohon maaf atas ketidak nyamanan yang dirasakan dalam proses booking service kami. Akan jadi masukan untuk kami lebih baik kedepan nya. Mohon dapat memberikan konfirmasi melalui WA booking service Auto2000 Garuda agar dapat kami tindak lanjuti. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.600649",
#     "name": "Rio Ardiansyah",
#     "link": "https://www.google.com/maps/contrib/117257155998565339108?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegUIARDdAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMShsicCrKMwaGOU25bGO1Bm9NY9m_4fZx9Ti7fk=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 1.0,
#     "review_date": "2023-05-14",
#     "review": "(Translated by Google) The spare part section doesn't respond, is it busy or isn't in a possible place (Original) Bagian sparepart didak merespon, sibuk atau gak ada di tempat mungkin",
#     "reply_date": "2023-05-14",
#     "reply": "(Translated by Google) Good Afternoon Mr. Rio Ardiansyah, Thank you for the review given, sorry for the lack of service provided by our spare parts team. If there are still problems/questions, please be able to provide complete data on the vehicle to our WA number 0877-8895-2000 for us to help with the process and follow up immediately. Thank You (Original) Selamat Siang Pak Rio Ardiansyah, Terima kasih atas review yang diberikan, mohon maaf atas kurang nya pelayanan yang diberikan oleh team sparepart kami. Jika masih ada kendala/pertanyaan mohon untuk dapat menginformasikan data lengkap kendaraan nya ke nomor WA kami 0877-8895-2000 untuk kami bantu proses dan tindak lanjuti segera. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.612672",
#     "name": "Suhartono Suhartono",
#     "link": "https://www.google.com/maps/contrib/109525458301165514112?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegUIARD3AQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMSEY0UpTyK6qcy8KtI2bB4by1Lbe6HQ_XVLs8BISbk=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-04",
#     "review": "(Translated by Google) For periodic servicing of 4-wheeled vehicles, especially Toyota, which has a better budget, in an auto, for a pocket budget that fits 2, I don't recommend it. (Original) Utk servis berkala kendaran roda 4 khusus nya Toyota yang punya bajet lebih ok di auto utk bajet kantong pas 2 an saya rekomendisikan jangan .",
#     "reply_date": "2023-05-04",
#     "reply": "(Translated by Google) Good Afternoon Mr Suhartono, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak Suhartono, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.620990",
#     "name": "Ryan Febryan Soekotjo",
#     "link": "https://www.google.com/maps/contrib/115520376092859739142?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegUIARCPAg",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMQCpBZ853WWOCq_zFPUKFlq01xCZ-RpSre6gzsXGQ=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-04",
#     "review": "(Translated by Google) Gives good information.... (Original) Memberikan informasi yang baik....",
#     "reply_date": "2023-05-04",
#     "reply": "(Translated by Google) Good Afternoon Mr Ryan, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak Ryan, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.625559",
#     "name": "Ambrita Fuadi",
#     "link": "https://www.google.com/maps/contrib/107504143598147074147?hl=en-US&sa=X&ved=2ahUKEwjaq9_uqqn_AhU4kYkEHT4uCEoQvvQBegUIARCnAg",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMQ47wFOcPOQgignxPeM5IkbqPra5IakB9D0XyfgPA=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-04",
#     "review": "",
#     "reply_date": "2023-05-04",
#     "reply": "(Translated by Google) Good afternoon, Sir, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.718296",
#     "name": "Ferry Jantho",
#     "link": "https://www.google.com/maps/contrib/108533987358742393181?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegQIARA7",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtf0bFzyzdFM19hdItxlQIbqiRkuPJpD-3Kd0Ztg=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-04",
#     "review": "(Translated by Google) Already booked 1 day before for service at 8 am. Arrived at 7.45, immediately served, overall service and service was good and fast. Because there are parts that have to be ordered for the parking camera components (wire and socket), so we need to go back again, Thanks Auto 2000 Garuda. (Original) Sdh booking 1 hari sebelumnya utk sevice jam 8 pagi. Tiba jam 7.45, lgs dilayani, overall pelayanan dan service nya bagus dan cepat. Karena ada parts yg harus dipesan pd komponen camera parkir (wire dan socket), jadi perlu balik lagi, Thanks Auto 2000 Garuda.",
#     "reply_date": "2023-05-04",
#     "reply": "(Translated by Google) Good Afternoon Mr Ferry, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak Ferry, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.723587",
#     "name": "Dwi Sutopo",
#     "link": "https://www.google.com/maps/contrib/112842724623217313521?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegQIARBT",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMTX8ay9qBQ6NyKWC6YCGUmWebWAc1wfXoGkODKZfj4=s40-c-c0x00000000-cc-rp-mo-ba3-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-04",
#     "review": "ok",
#     "reply_date": "2023-05-04",
#     "reply": "(Translated by Google) Good Afternoon Mr Dwi, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak Dwi, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.732241",
#     "name": "margaretha dianaji",
#     "link": "https://www.google.com/maps/contrib/117777985105262435759?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegQIARBr",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMQJ04z3XN-NjWF1hcEzoLPd-pxAzp50pJgIamPvfaw=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-05-04",
#     "review": "(Translated by Google) Satisfactory service, Sales Alfonsus Thomas excellent👍 (Original) Pelayanan muaskan, Sales Alfonsus Thomas excellent👍",
#     "reply_date": "2023-05-04",
#     "reply": "(Translated by Google) Good Afternoon Margaretha Dianaji, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Ibu Margaretha Dianaji, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.739191",
#     "name": "Galih Fujiastuti",
#     "link": "https://www.google.com/maps/contrib/106166723548216809760?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegUIARCDAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTteA3EOx_XxMLxMzv9kGO5p10gA1XPTlsDPk6Jrd=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-04-04",
#     "review": "",
#     "reply_date": "2023-05-04",
#     "reply": "(Translated by Google) Good Afternoon Mr Galih, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak Galih, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.758427",
#     "name": "Amin Dermawan",
#     "link": "https://www.google.com/maps/contrib/105062408631923733513?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegUIARCYAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtfoV2pliqog1CsX5_M_GePqjFLqz8oHs0RhX8rt=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-04-04",
#     "review": "",
#     "reply_date": "2023-04-04",
#     "reply": "(Translated by Google) Good afternoon, Sir, Thank you for the review given, happy to be able to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak, Terima kasih atas review yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.787017",
#     "name": "Febyansyah Putra Syahrizal, S.E.",
#     "link": "https://www.google.com/maps/contrib/104178873855812918223?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegUIARCtAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMSgOmCaj7EgMKtvH-FPnbbpuxG_tCTMEF57_n23Yw=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-04-04",
#     "review": "(Translated by Google) The second best Toyota service place, after Auto2000 Pondok Indah. Fast service, satisfied, friendly service. (Original) Tempat service Toyota terbaik kedua, setelah Auto2000 pondok indah. Service cepat, puas, pelayanan ramah.",
#     "reply_date": "2023-04-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.810862",
#     "name": "Silvia Kadiri",
#     "link": "https://www.google.com/maps/contrib/102033855668325064366?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegUIARDFAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtcdC_9QDb6HrZRlsmTR6fIqKdHf4XNsspFk78BU=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-04-04",
#     "review": "(Translated by Google) SERVICENN PAK BUDI TOYOTA 2000 GARUDAAAAAA OUTSTANDING BIASYAAAHHH!!! this is the umpteenth time buying a car.. AWESOME.. AWESOME.. MANTAAPPP (Original) PELAYAAANANNN PAK BUDI TOYOTA 2000 GARUDAAAAAA LUARRR BIASYAAAHHH!!!ini pembelian mobil yang kesekian kalinyaa.. MANTAPP..MANTAPPP.. MANTAAPPP",
#     "reply_date": "2023-04-04",
#     "reply": "(Translated by Google) Good afternoon Miss Silvia, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Waiting for the next order, ma'am. Thank You (Original) Selamat siang Ibu Silvia, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Ditunggu orderan selanjut nya ya bu. Terima kasih",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipNpQC1jmUkKjjmKJ_9P6sLMn_Y8jE__hw_FEdAq=w100-h100-p-n-k-no",
#       "https://lh5.googleusercontent.com/p/AF1QipM_2wrVUlr7_VyJaSl5rv6Gk8NLRHc6MctXwVVM=w100-h100-p-n-k-no",
#       "https://lh5.googleusercontent.com/p/AF1QipM234pSWt2mHih6Nc5ij3YYND7cYn2tJEadB0Ls=w100-h100-p-n-k-no"
#     ],
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.829555",
#     "name": "Eko Fitrianto",
#     "link": "https://www.google.com/maps/contrib/102736098065495712734?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegUIARDhAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMRs1g7_cKprIJ6QdeN-tVBlwJ2ccvRHeYoy7p9HnQ=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 5.0,
#     "review_date": "2023-04-04",
#     "review": "",
#     "reply_date": "2023-04-04",
#     "reply": "(Translated by Google) Good afternoon Mr Eco, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang Pak Eko, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.842329",
#     "name": "Satriyo JP",
#     "link": "https://www.google.com/maps/contrib/110567041342294765250?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegUIARD2AQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtf_58rgNYdTpY-MxhX_z1MAjFANjv-a1lLFXbcS=s40-c-c0x00000000-cc-rp-mo-ba3-br100",
#     "rating": 5.0,
#     "review_date": "2023-04-04",
#     "review": "(Translated by Google) The staff are friendly and cooperative... 👍 (Original) Petugasnya ramah dan kooperatif.. 👍",
#     "reply_date": "2023-04-04",
#     "reply": "(Translated by Google) Good Afternoon Mr Satriyo, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak Satriyo, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:01.852186",
#     "name": "Dody Marthen",
#     "link": "https://www.google.com/maps/contrib/111965309718107602543?hl=en-US&sa=X&ved=2ahUKEwiRlN_vqqn_AhXCF1kFHW3jCLoQvvQBegUIARCOAg",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMRdy3MiwNhlGPxIPsqOozFFA7kvkKDp3wLWRwzi=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-04-04",
#     "review": "nice place",
#     "reply_date": "2023-04-04",
#     "reply": "(Translated by Google) Good Afternoon Mr. Dody Marthen, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang Pak Dody Marthen, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.026692",
#     "name": "Sugiarto Yanto",
#     "link": "https://www.google.com/maps/contrib/106057363104829711918?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegQIARA7",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtdWSbZNSudyh__km-83w_ZF9iRZTR2r0AlGmiOn=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-04-04",
#     "review": "",
#     "reply_date": "2023-04-04",
#     "reply": "(Translated by Google) Good afternoon Mr Sugiarto, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang Pak Sugiarto, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.055537",
#     "name": "ASHOK MURJANI",
#     "link": "https://www.google.com/maps/contrib/117632141312703225106?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegQIARBQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtedjCgGsjj4nVjW14CKNuS31o4P0aAwuN0thDXS=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "Very good",
#     "reply_date": "2023-04-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.087416",
#     "name": "sholawat Jibril",
#     "link": "https://www.google.com/maps/contrib/105564043291575363596?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegQIARBo",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtcavA_7d28HOpyjli7Z_BWl8Mb6NXS6u1vXouWd=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 4.0,
#     "review_date": "2023-03-04",
#     "review": "",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the review given, happy to be able to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang, Terima kasih atas review yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.110904",
#     "name": "Ade Kinkin",
#     "link": "https://www.google.com/maps/contrib/113653482587311322850?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegQIARB9",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTteigsOI88HraCu6amDvr1ykK_vSFGxVdq8H0Awc=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.145167",
#     "name": "Evans Gunter",
#     "link": "https://www.google.com/maps/contrib/108464074005744816590?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegUIARCSAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMT2AmMz4WEBZIkEEYc8YQiMzoOCfd2z-EfE-N5AcA=s40-c-c0x00000000-cc-rp-mo-ba3-br100",
#     "rating": 1.0,
#     "review_date": "2023-03-04",
#     "review": "(Translated by Google) An appointment with an auto2000 Garuda salesperson to test drive Voxy (meet at the exhibition, Mal Kelapa Gading). Directed to TDE on Lake Sunter, he said just look for him and he will be accompanied. D-day arrived at TDE. Not registered. Call sales. not lifted. Waste of time. Auto move to the next shop. (Original) Janjian sama seorang sales auto2000 garuda untuk test drive voxy (ketemu di pameran, mal kelapa gading). Diarahkan ke TDE di danau sunter, katanya cari dia aja dan akan ditemani. Hari H sampai di TDE. Gak didaftarkan. Telpon sales. ga diangkat. Buang waktu. Auto pindah ke toko sebelah.",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good Evening Mr. Evans, Thank you for the review given, we are very sorry for the poor service provided by one of our sales. Sorry for the inconvenience, sir. Please provide more detailed information to WA Number 0877-8895-2000 or Tel 021-425-2000 so we can follow up immediately. Thank You (Original) Selamat Malam Pak Evans, Terima kasih atas review yang diberikan, kami sangat menyesal atas pelayanan yang kurang baik dilakukan oleh salah satu sales kami. Mohon maaf atas ketidak nyamanan nya ya pak. Mohon informasikan lebih detail ke Nomor WA 0877-8895-2000 atau Telpon 021-425-2000 agar dapat kami tindak lanjuti segera. Terima kasih",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipPjRau6nvihTYe8VDmzxBvDZkGgrfTvVlY0OTuF=w100-h100-p-n-k-no",
#       "https://lh5.googleusercontent.com/p/AF1QipNcJemjXBpRvQRpXIb_dpZD-KSiGyMu2eimubjF=w100-h100-p-n-k-no"
#     ],
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.172058",
#     "name": "Ojit Jan",
#     "link": "https://www.google.com/maps/contrib/103620028774665559229?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegUIARCtAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMS62n0mwXf5q7ydHIaJGE-iTkkV-bcp1lgP1OAMMA=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat Siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.205082",
#     "name": "Elly Jhon Pandoh",
#     "link": "https://www.google.com/maps/contrib/100970997184613529869?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegUIARDCAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMQElsFXMMlBdqkMWmG8NxvuoFJcw45bzERWce1S6A=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You. (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih.",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.254411",
#     "name": "Achmad Septiandi S",
#     "link": "https://www.google.com/maps/contrib/107460019666089537402?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegUIARDXAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMShaUHE2K-8Psu64kj0AGhmo8TxhnmyyGMA1-B9=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "(Translated by Google) Auto 2000 here the service is fast then the advice given is also in accordance with the damage .. great anyway (Original) Auto 2000 di sini pelayanannya cepat kemudian saran yang di berikan juga sesuai dengan kerusakan.. mantep deh pokoknya",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon Mr. Achmad Septiandi, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You. (Original) Selamat siang Pak Achmad Septiandi, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih.",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.295063",
#     "name": "Kang Mpeb",
#     "link": "https://www.google.com/maps/contrib/117214663939344636969?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegUIARDvAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMSkUwK52ATJcGwATd2zgna_mFLzhdVNbx3r8tFe=s40-c-c0x00000000-cc-rp-mo-ba5-br100",
#     "rating": 1.0,
#     "review_date": "2023-03-04",
#     "review": "(Translated by Google) Since this is an official Toyota repair shop, my expectation for the service here is that the mechanic and CS can provide the right information and actions for the car that I just got hold of. Of the 2 times of service (within 1 week, Saturday and Wednesday), there weren't many recommendations for repairs, so I thought the car was in good condition, and fit to be taken out of town. In fact, my car overheated when I returned to Jakarta, and the initial indication of illness was a leaking radiator. Daannn, that includes the service package that was done during the previous service. So, what did the mechanic do when my car was inspected? Light checks? Just take a look? It's pretty big, I'll service it there. Since it's not long after service (Wednesday to Sunday in the same week), I'm confident that I contact the auto2000 call center, assuming there's still warranty. Instead, I was directed to exit the Purwakarta toll road, almost 30 km from where my car broke down in the Kalijati area, Subang. There was no choice, I looked for the nearest toll exit and was forced to follow along and was directed to a regular repair shop. recommended by this CS-it's also free. \"Don't want to be lied to by the mechanic for disassembling it, just replace the radiator\". My position is almost late, plus I have a small child. If I follow the advice, I should take the car to Jakarta. How do I do that? I've been thinking positively that Call Center auto2000 will help and be responsible, since my car has just been serviced there, in the end it takes care of it and takes care of my own money. I'm tired of dealing with this official repair shop. Very different from Service Suzuki. (Original) Karena ini bengkel resmi Toyota, ekspektasi gw service disini adalah montir dan CS-nya bisa kasi info dan tindakan yang tepat buat mobil yang baru gw pegang. Dari 2 kali service (dalam waktu 1 minggu, Sabtu dan Rabu), rekomendasi perbaikan nggak banyak, jadi gw pikir kondisi mobil oke, dan fit untuk dibawa ke luar kota. Nyatanya, mobil gw overheat pas balik ke Jakarta, dan penyakitnya terindikasi awal dari radiator yang bocor. Daannn, itu termasuk paket service yang sudah dilakukan pas service sebelumnya. Lantas, apa yang dilakukan montir pas mobil gw diperiksa? Cek-cek ringan? Cuma nengok2 dikit? Lumayan abis gede lo, gw service disana. Karena masih nggak lama dari service (hari Rabu ke Minggu di pekan yang sama), pede dong gw kontak call center auto2000, dengan asumsi masih ada garansi. Malah diarahkan agar keluar tol Purwakarta, nyaris 30 km lebih dari tempat mobil gw mogok di daerah Kalijati Subang. Gak ada pilihan lah, gw nyari exit tol terdekat dan terpaksa ngikut diarahin ke bengkel biasa. disaranin sama CS ini-itu juga percuma. \"Jangan mau dibohongi montir buat bongkar2 lah, cukup ganti radiator lah\". Posisi gw nyaris malem, plus bawa anak kecil. Kalo ngikutin saran harus gw bawa ke Jakarta mobilnya Gimana caranya? Udah berpikir positif Call Center auto2000 bakal bantu dan tanggung jawab, secara mobil gw baru diservice-in disana, ujung2nya ngurus dan nguras duit sendiri. Kapok gw urusan sama bengkel resmi ini. Beda banget ama Service Suzuki.",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the review provided, sorry for the unpleasant experience you had during the repair at the Auto2000 Workshop. Please provide complete information about your vehicle to our number (WA 0877-8895-2000) or telephone 021-425-2000 so we can follow up immediately. Thank You (Original) Selamat siang, Terima kasih atas review yang diberikan, mohon maaf atas pengalaman yang dialami kurang menyenangkan selama perbaikan di Bengkel Auto2000. Mohon untuk dapat memberikan informasi lengkap kendaraan anda ke nomor kami (WA 0877-8895-2000) atau Telpon 021-425-2000 agar dapat kami tindak lanjuti segera. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.326692",
#     "name": "Jonson Zhuo",
#     "link": "https://www.google.com/maps/contrib/118280051033519814012?hl=en-US&sa=X&ved=2ahUKEwjFxKbxqqn_AhW2l2oFHUmLDpcQvvQBegUIARCHAg",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtf3jWHpmy0Wq6jo-PMBnv35cWiz_6jvR4jnvrmu=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "(Translated by Google) The service is satisfying. The car when taken was ready to use and according to the request. Thanks Mr. Yanchie for helping. Good luck for the future (Original) Pelayanannya memuaskan. Mobil saat diambil dalam kondisi siap pakai dan sesuai request. Thanks Pak Yanchie sudah dibantu. Sukses selalu",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon Mr. Jonson Zhuo, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You. (Original) Selamat siang Pak Jonson Zhuo, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih.",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.499131",
#     "name": "syahrul febrianto",
#     "link": "https://www.google.com/maps/contrib/101117851502645937902?hl=en-US&sa=X&ved=2ahUKEwjEyKvyqqn_AhWJFlkFHdteAd4QvvQBegQIARA7",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMQ_tE3g_1onuwAR2PgyfqWUQrR_msPQ3496BG0v=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "(Translated by Google) The service here is satisfying and well served. SA and Sales are TOP 👍👍 Recommendation to Auto2000 Garuda (Original) Service disini memuaskan dan dilayani dengan baik. SA dan Sales nya TOP 👍👍 Rekomendasi ke Auto2000 Garuda",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon Mr. Syahrul Febrianto, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You. (Original) Selamat siang Pak Syahrul Febrianto, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih.",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.520501",
#     "name": "Titin Nurasih",
#     "link": "https://www.google.com/maps/contrib/107589589148028746282?hl=en-US&sa=X&ved=2ahUKEwjEyKvyqqn_AhWJFlkFHdteAd4QvvQBegQIARBT",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtcnXw85IOw7w2pXmKpaqjImk9bWcHsSryCzi8_0=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "(Translated by Google) The service is very satisfying, the staff is friendly and fast... highly recommend (Original) Sangat memuaskan pelayanannya staf stafnya ramah dan cepat..sangat recomendasi dah",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You. (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih.",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.542515",
#     "name": "Andri Kusriyanto",
#     "link": "https://www.google.com/maps/contrib/118126592050041228414?hl=en-US&sa=X&ved=2ahUKEwjEyKvyqqn_AhWJFlkFHdteAd4QvvQBegQIARBr",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMSh-fmHcnNFpoyvwiM3OkPENyLpHR7O8Ryp70jS=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-03-04",
#     "review": "",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon Mr. Andri Kusriyanto, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank You (Original) Selamat siang Pak Andri Kusriyanto, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.569920",
#     "name": "AY Maink",
#     "link": "https://www.google.com/maps/contrib/111782083908456590026?hl=en-US&sa=X&ved=2ahUKEwjEyKvyqqn_AhWJFlkFHdteAd4QvvQBegUIARCAAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMR13m_gQQlPtVPcVIz3Fzmcf3qHs6pxwx7qjo2W9x8=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 5.0,
#     "review_date": "2023-02-04",
#     "review": "",
#     "reply_date": "2023-03-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.588140",
#     "name": "Irkham Ardiansyah",
#     "link": "https://www.google.com/maps/contrib/115067851053724004197?hl=en-US&sa=X&ved=2ahUKEwjEyKvyqqn_AhWJFlkFHdteAd4QvvQBegUIARCVAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTte-77kIWFy2IlW4twnEmr9d5hpyo-FIG-1N_SOJ=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-02-04",
#     "review": "Top",
#     "reply_date": "2023-02-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.603875",
#     "name": "Aqil Qloen",
#     "link": "https://www.google.com/maps/contrib/116049143978083016853?hl=en-US&sa=X&ved=2ahUKEwjEyKvyqqn_AhWJFlkFHdteAd4QvvQBegUIARCtAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMS7LTUoo_qhQ1B7Pr8wYQd2PL5n_RhGSdCSCBe_6g=s40-c-c0x00000000-cc-rp-mo-ba4-br100",
#     "rating": 3.0,
#     "review_date": "2023-02-04",
#     "review": "(Translated by Google) For vehicle service OK, for driver service and the waiting room is not okay. There is an inscription that coffee & tea are available, only coffee and tea are in the Pantry Cleaning Service, we are visitors, as long as we enter, it's not good, we want to order coffee, but CS is rarely in the room, it's good to get food here, but when we're late, when we're allotted we didn't get it, even though there's still a lot of stock not because it's run out. More to CS, it's more standby in the service waiting room, we want to complain about the room where the air conditioner isn't blamed, it's also confusing, sometimes it's cold, sometimes it's hot, sometimes it's too cold. Auto 2000 Garuda, Kemayoran (Original) Untuk service kendaraannya OKE, untuk service drivernya dan ruang tunggunya gak oke. Ada tulisan tersedia kopi & teh, cuma kopi sama tehnya ada di Pantry Cleaning Service, kita pengunjung mau asal masuk kan gak enak, mau mesen kopi tapi CS jarang di ruangan, disini bagus sih dapet makan, tapi di saat kita telat masuk pas jatah pembagian kita gak kebagian, padahal stock masih banyak bukan karna keabisan. Lebih ke CS nya lebih standby lagi di ruang tunggu service, kita mau komplain terkain ruangan yang ac gak di nyalahin juga bingung, kadang dingin kadang panas, kadang terlalu dingin. Auto 2000 Garuda, Kemayoran",
#     "reply_date": "2023-02-04",
#     "reply": "(Translated by Google) Good afternoon Mr Aqil, Thank you for the 3 star review given along with the criticisms and suggestions. We apologize for our waiting room attendants who are not always there. It will be a note for us to be able to improve services at Auto2000 Garuda. Please provide complete information on Mr. Aqil's vehicle number to our number 0877-8895-2000 so we can follow up immediately. Thank you (Original) Selamat siang Pak Aqil, Terima kasih atas review bintang 3 yang diberikan beserta kritik dan saran nya. Mohon maaf untuk petugas ruang tunggu kami yang tidak selalu berada ditempat. Akan jadi catatan untuk kami dapat meningkatkan pelayanan di Auto2000 Garuda. Mohon untuk dapat memberikan info lengkap nopol kendaraan Pak Aqil ke nomor kami 0877-8895-2000 agar dapat kami tindak lanjuti segera. Terima kasih",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipNQ04m9gpSJgHNixs7w3rF7dy7D2-iFeTt9ekC6=w100-h100-p-n-k-no"
#     ],
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.622636",
#     "name": "Andyka Lim",
#     "link": "https://www.google.com/maps/contrib/115267555196180529306?hl=en-US&sa=X&ved=2ahUKEwjEyKvyqqn_AhWJFlkFHdteAd4QvvQBegUIARDHAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtdvdo3xW0ruLdRoBFK3iidAtqDpLOwWDw9dzVrv=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 3.0,
#     "review_date": "2023-02-04",
#     "review": "",
#     "reply_date": "2023-02-04",
# ...
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.794655",
#     "name": "Ali Sodikin",
#     "link": "https://www.google.com/maps/contrib/103299362685817461546?hl=en-US&sa=X&ved=2ahUKEwifz6_zqqn_AhWQjYkEHW63D7YQvvQBegUIARCtAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMRRiz7ngXLBJtd-S_Vedy3sXnTWyFRkhtNsTH3I=s40-c-c0x00000000-cc-rp-mo-ba2-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) Friendly, friendly and comfortable service (Original) Pelayanan ramah, bershabat dan nyaman",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, happy to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang, Terima kasih review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.805129",
#     "name": "amut 17",
#     "link": "https://www.google.com/maps/contrib/103363709461625075760?hl=en-US&sa=X&ved=2ahUKEwifz6_zqqn_AhWQjYkEHW63D7YQvvQBegUIARDFAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMTvl9LK5m4Ho5NFy-WkTlsKhpvOA8fIqBJdpixj=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) very extraordinary, thank you Mr. Ali Sodikin (Original) sangat luar biasa, terima kasih Pak Ali Sodikin",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, happy to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang, Terima kasih review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.813419",
#     "name": "Widodo Santoso",
#     "link": "https://www.google.com/maps/contrib/104129338223774095968?hl=en-US&sa=X&ved=2ahUKEwifz6_zqqn_AhWQjYkEHW63D7YQvvQBegUIARDdAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtcqsiLuwSc1G2DNE9-yhxWhbyc3F18Bt7mVD09B=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) The service is good(Original)Pelayanan nya bagus",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon Mister Widodo, Thank you for the 5 star review given, happy to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang Pak Widodo, Terima kasih review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.817418",
#     "name": "Maria Wijayanti",
#     "link": "https://www.google.com/maps/contrib/105950809421605823119?hl=en-US&sa=X&ved=2ahUKEwifz6_zqqn_AhWQjYkEHW63D7YQvvQBegUIARD1AQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTteoo25pLXfMPfJGIe_0Cq1C6vYIiy9bhdYGmWZh=s40-c-c0x00000000-cc-rp-mo-ba2-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) Good service, turnaround time... (Original) Pelayanan baik, waktu pengerjaan sesuai..",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon Mother Mary, Thank you for the 5 star review given, happy to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang Ibu Maria, Terima kasih review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.819928",
#     "name": "trisman surya",
#     "link": "https://www.google.com/maps/contrib/110352936360117630325?hl=en-US&sa=X&ved=2ahUKEwifz6_zqqn_AhWQjYkEHW63D7YQvvQBegUIARCNAg",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtc9B7hlMAOguWcyFbw3n-B0W0sFo2DSOnRiVKH0=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 1.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) very bad service, came in at 8 in the morning, the info was finished at 11, you know, at 11 I didn't hold it yet, the info was finished at 3 (Original) pelayanan sangat buruk,masuk jam 8 pagi infonya kelar jam 11 tau2nya jam 11 belum pegang juga,info lagi kelarnya jam 3",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon Mr. Trisman Surya, Thank you for the review that has been given, sorry for the difficulties experienced. Please provide the police number and cellphone number that we can call to number 0877-8895-2000 so we can follow up immediately. Thank you (Original) Selamat siang Bpk Trisman Surya, Terima kasih review yang telah diberikan, mohon maaf atas kendala yang dialami. Mohon infokan nomor polisi dan no hp yang bisa kami hubungi ke nomor 0877-8895-2000 agar dapat kami tindak lanjuti segera. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.918592",
#     "name": "Viceroy theking",
#     "link": "https://www.google.com/maps/contrib/117126954058191344212?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegQIARA7",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtcTJ4l39YGTsW5WgrSS7u_sbUULq0Jp82Vr_w24=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 1.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) Very bad service here Promise to finish at 12 when I was asked if it was finished, then the information was not held, it was finished at 3 o'clock again, even though I was waiting in the waiting room, the information was not received (Original) Pelayanan sangat buruk disini Janji selesai jam 12 pas di tanya udh kelar baru info kalau belum di pegang,selesai nya jam 3 lagi,padahal saya tunggu di runag tunggu nggak di info2",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the review that has been given, sorry for the difficulties experienced. Please provide the police number and cellphone number that we can call to number 0877-8895-2000 so we can follow up immediately. Thank you (Original) Selamat siang, Terima kasih review yang telah diberikan, mohon maaf atas kendala yang dialami. Mohon infokan nomor polisi dan no hp yang bisa kami hubungi ke nomor 0877-8895-2000 agar dapat kami tindak lanjuti segera. Terima kasih",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipMzv-CYvPcmcGroLuh58EDQN9nxmnosgEN_seEr=w100-h100-p-n-k-no"
#     ],
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.929641",
#     "name": "Lisha Handriani",
#     "link": "https://www.google.com/maps/contrib/101795827024743767108?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegQIARBV",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtc37wFurU9N-crqWn3cnlpibOov6GE3aBJXRiUz=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) Good service, solution, fast and responsive👍👍👍 (Original) Pelayanan baik, solutif, cepat dan responsif👍👍👍",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon Miss Lisa, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang Ibu Lisha, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.934194",
#     "name": "eli damayanti",
#     "link": "https://www.google.com/maps/contrib/111017516817346391798?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegQIARBt",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTte2CveFZlCLEtEE4EiEhM5U2c6jsNTbzYH9Gzi2=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon Miss Eli, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang Ibu Eli, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.937285",
#     "name": "randu baya",
#     "link": "https://www.google.com/maps/contrib/117236828966259450171?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegUIARCBAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMTkkjlK7QUrHUgWd_Fo7O1wJozhnAeYgwuJJMAadDE=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) The service is very friendly(Original)Pelayananya sangat ramah",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon Mr. Randi, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang Bapak Randu, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.947364",
#     "name": "Aria Gusti Narendra",
#     "link": "https://www.google.com/maps/contrib/117879320669945229037?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegUIARCZAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMTfqYMZmn60c1_FWnkOH__Ns56ISAnJg4hpoLGAOw=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 1.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) cs rese can not buy my car (Original) cs nya rese ga boleh beli mobil saya",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good morning Mr. Aria Gusti Narendra, Sorry for the review given, what do you mean, sir? please inform us directly at number 0877-8895-2000 so that we can immediately follow up on these problems. Waiting for confirmation, sir. Thank you (Original) Selamat pagi Bapak Aria Gusti Narendra, Mohon maaf atas review yang diberikan, ini maksudnya bagaimana ya pak? boleh di infokan langsung kepada kami di nomor 0877-8895-2000 agar dapat kami segera tindak lanjuti kendala tersebut. Ditunggu konfirmasi nya ya pak. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.952369",
#     "name": "Muhammad Farhan Huda",
#     "link": "https://www.google.com/maps/contrib/106381078903627658146?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegUIARCxAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMSJNHgkdTVsH9fn3vP1N9ykQusNRthdx26zgHW0zg=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.954127",
#     "name": "Emilia Yoanita",
#     "link": "https://www.google.com/maps/contrib/112622878092369113547?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegUIARDGAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMSiPuwsHf45yFaPGv4A1nWnsae6xiwOkkry8qGNfg=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.965347",
#     "name": "fachry gozhali",
#     "link": "https://www.google.com/maps/contrib/108447932540982864232?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegUIARDaAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMTWjMtnypa6Adl8Wq4jw81X8YrNTOKavFyIgdsQHg=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.969350",
#     "name": "Jessica Gale",
#     "link": "https://www.google.com/maps/contrib/111799955195163892717?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegUIARDuAQ",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/AD_cMMS237c1wM7Ia3qUTXG14EX48gtzaJMJqfbIDdlnbA=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "(Translated by Google) the service is friendly, the sales are cute, and the service is fast 👍👍 (Original) pelayanannya ramah, salesnya cakep cakep, dan pelayanan servis nya cepat 👍👍",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon Ms. Jessica Gale, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang Ibu Jessica Gale, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "scraped_date": "2023-06-04T17:04:02.977833",
#     "name": "Reza Andriana",
#     "link": "https://www.google.com/maps/contrib/111117975206995073867?hl=en-US&sa=X&ved=2ahUKEwiriaL0qqn_AhVKF1kFHf3mBbMQvvQBegUIARCGAg",
#     "thumbnail": "https://lh3.googleusercontent.com/a/AAcHTtdRFYlM2faV5baplmEeXRPTt1qvx1u6TIKrEij2=s40-c-c0x00000000-cc-rp-mo-br100",
#     "rating": 5.0,
#     "review_date": "2023-01-04",
#     "review": "",
#     "reply_date": "2023-01-04",
#     "reply": "(Translated by Google) Good afternoon, Thank you for the 5 star review given, it's a pleasure to provide satisfying service. We look forward to welcoming him back to Auto2000 Garuda. Thank you (Original) Selamat siang, Terima kasih atas review bintang 5 yang diberikan, senang dapat memberikan pelayanan yang memuaskan. Kami nantikan kedatangan nya kembali di Auto2000 Garuda. Terima kasih",
#     "images": null,
#     "local_guide": null
#   }
# ]

# %% [markdown]
# <h1><center>Melakukan <i>Data Cleaning</i></center></h1>

# %% [markdown]
# Mengubah hasil *scraping* dari JSON ke Pandas *dataframe* agar lebih mudah dibaca.

# %%
columns = [
    "scraped_date", "name", "link", "rating", "review_date", "english_review", "indonesian_review",
    "reply_date", "english_reply", "indonesian_reply", "images", "local_guide"
]

df = pd.DataFrame(reviews)

df["local_guide"] = df["local_guide"].apply(lambda x: False if x is not True else True)

df = df.fillna(np.nan)
df = df.replace("", np.nan)

# for col in ["scraped_date", "review_date", "reply_date"]:
#     df[col] = pd.to_datetime(df[col])

df["english_review"] = df["review"].str.extract(r"\(Translated by Google\)\s+(.*?)\s+\(Original\)")
df["english_review"] = df["english_review"].str.strip()

df["indonesian_review"] = df["review"].str.extract(r"\(Original\)\s+(.*)")
df["indonesian_review"] = df["indonesian_review"].str.strip()

df["english_reply"] = df["reply"].str.extract(r"\(Translated by Google\)\s+(.*?)\s+\(Original\)")
df["english_reply"] = df["english_reply"].str.strip()

df["indonesian_reply"] = df["reply"].str.extract(r"\(Original\)\s+(.*)")
df["indonesian_reply"] = df["indonesian_reply"].str.strip()

df = df[columns]

df.head()
# Out:
#                  scraped_date            name  \
# 0  2023-06-04T17:04:01.575563     Sonny Angga
# 1  2023-06-04T17:04:01.579560     Ade Pardana
# 2  2023-06-04T17:04:01.584098  Cahyadi Wijaya
# 3  2023-06-04T17:04:01.588076   Tukang Review
# 4  2023-06-04T17:04:01.594660       Yesi Yoto
#
#                                                 link  rating review_date  \
# 0  https://www.google.com/maps/contrib/1140089559...     5.0  2023-05-28
# 1  https://www.google.com/maps/contrib/1059841397...     5.0  2023-05-28
# 2  https://www.google.com/maps/contrib/1178533912...     5.0  2023-05-28
# 3  https://www.google.com/maps/contrib/1044526187...     5.0  2023-05-28
# 4  https://www.google.com/maps/contrib/1024983469...     5.0  2023-05-28
#
#                                       english_review  \
# 0  Thank you Pa Ade for the good and extraordinar...
# 1                                                NaN
# 2  Good service, fast, friendly, served by Mr. Ad...
# 3  Auto 2000 Garuda service is great. Thank you f...
# 4                                                NaN
#
#                                    indonesian_review  reply_date  \
# 0  Terima kasih Pa Ade atas pelayanan yang baik d...  2023-05-30
# 1                                                NaN  2023-05-30
# 2  Pelayanang Baik, Cepat , Ramah, dilayani Pak A...  2023-05-30
# 3  Pelayanan Auto 2000 Garuda mantap. Terima kasi...  2023-05-30
# 4                                                NaN  2023-02-04
#
#                                        english_reply  \
# 0  Good afternoon Mr. Sonny Angga, Thank you for ...
# 1  Good afternoon. Thank you for the 5 star revie...
# 2  Good afternoon Mr. Cahyadi Wijaya, Thank you f...
# 3  Good afternoon AutoFamily. Thank you for the 5...
# 4  Good afternoon Mr. Yesi Yoto. Thank you for th...
#
#                                     indonesian_reply  \
# 0  Selamat siang Pak Sonny Angga, Terima kasih at...
# 1  Selamat siang. Terima kasih atas review bintan...
# 2  Selamat siang Pak Cahyadi Wijaya, Terima kasih...
# 3  Selamat siang AutoFamily. Terima kasih atas re...
# 4  Selamat siang Pak Yesi Yoto. Terima kasih atas...
#
#                                               images  local_guide
# 0                                                NaN        False
# 1                                                NaN        False
# 2  [https://lh5.googleusercontent.com/p/AF1QipOaO...        False
# 3                                                NaN        False
# 4  [https://lh5.googleusercontent.com/p/AF1QipMmE...         True

# %% [markdown]
# Menyimpan hasil *scraping* dalam bentuk Excel.

# %%
df.to_excel("result.xlsx", index=False)
